# %% [markdown]
# [나무위키](https://namu.wiki/w/%EC%95%84%EB%AF%B8%EB%85%B8%EC%82%B0)
#
# > fs (frameshift): 변이가 일어난 후 프레임시프트가 발생하여 이후의 아미노산 서열이 잘못 읽히게 되고,
# > 보통 **종결 코돈(stop codon)**이 빨리 나타나 단백질이 비정상적으로 짧아지게 됩니다.

# %%
import re
from keras.preprocessing.sequence import pad_sequences

amino_acid_dict = {
    'A': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'K': 9, 'L': 10, 
    'M': 11, 'N': 12, 'P': 13, 'Q': 14, 'R': 15, 'S': 16, 'T': 17, 'V': 18, 'W': 19, 'Y': 20
}

def one_hot_encode(amino_acids):
    # 20차원 벡터 생성
    amino_acid_dict = {aa: idx for idx, aa in enumerate('0ACDEFGHIKLMNPQRSTVWY', start=1)}
    vector = np.zeros((len(amino_acids), 21))  # 20개의 아미노산
    for i, aa in enumerate(amino_acids):
        if aa in amino_acid_dict:
            vector[i, amino_acid_dict[aa] - 1] = 1  # 원핫 인코딩
    return vector

def extract_numbers(s):
    # 입력값이 문자열이 아닐 경우 문자열로 변환
    if not isinstance(s, str):
        s = str(s)
    match = re.match(r"([A-Za-z]+)(\d+)([A-Za-z]+)", s)
    if match:
        original = match.group(1)  # 첫 번째 그룹: 원래 아미노산
        position = match.group(2)             # 두 번째 그룹: 변이 위치
        new = match.group(3)       # 세 번째 그룹: 새로운 아미노산
        return original, position, new
    else:
        None

# 데이터에서 각 서열을 인코딩하는 함수
def encode_sequence(sequence):
    return [amino_acid_dict[aa] for aa in sequence]

# %%
for i in tqdm(X.columns):
    A = pd.DataFrame(columns=['Original','Position','New'])
    for j in range(len(X)):
        A.loc[j, A.columns] = extract_numbers(X.loc[j, i])

    A = A.fillna(0)

    A['Original'] = A['Original'].map(lambda x : str(x) if x == 0 else x)

    # 원핫 인코딩 적용
    A['Original'] = A['Original'].apply(one_hot_encode)

    ## NEW
    A['New'] = A['New'].map(lambda x : -1 if x == 'fs' else x)

    A['New'] = A['New'].map(lambda x : str(x) if x == 0 else x)
    A['New'] = A['New'].map(lambda x : str(x) if x == -1 else x)

    # 원핫 인코딩 적용
    A['New'] = A['New'].apply(one_hot_encode)
    
    for n in range(len(A)):
        B = []
        for n_1 in range(21):
            B.append(A.loc[n, 'Original'][0][n_1].tolist())
            
        B.append(A.loc[n, 'Position'])
        
        for n_2 in range(21):
            B.append(A.loc[n, 'New'][0][n_2].tolist())
            
        X[i] = X[i].astype('str')
        X.at[n, i] = B

# %%
for i in tqdm(X.columns):
    A = pd.DataFrame(columns=['Original','Position','New'])
    for j in range(len(X)):
        A.loc[j, A.columns] = extract_numbers(X.loc[j, i])

    A = A.fillna(0)

    # Original

    # for k in range(len(A)):
    #     try:
    #         encoded_data = [encode_sequence(seq) for seq in A.loc[k, 'Original']]
    #         A.loc[k, 'Original'] = encoded_data
    #     except:
    #         pass

    # A['Original'] = A['Original'].map(lambda x : [[0]] if x == 0 else x)

    A['Original'] = A['Original'].map(lambda x : str(x) if x == 0 else x)

    # 원핫 인코딩 적용
    A['Original'] = A['Original'].apply(one_hot_encode)

    # a = 0
    # for l in A['Original'].value_counts().index:
    #     if len(l) > a :
    #         a = len(l)
    #     else:
    #         pass

    # print(A.head())
    
    # padded_sequences = pad_sequences(A['Original'].tolist(), maxlen=21, padding='post')
    
    # A['Original'] = list(padded_sequences)

    ## NEW
    A['New'] = A['New'].map(lambda x : -1 if x == 'fs' else x)

    # for m in range(len(A)):
    #     try:
    #         encoded_data = [encode_sequence(seq) for seq in A.loc[m, 'New']]
    #         A.loc[m, 'New'] = encoded_data
    #     except:
    #         pass

    A['New'] = A['New'].map(lambda x : str(x) if x == 0 else x)
    A['New'] = A['New'].map(lambda x : str(x) if x == -1 else x)

    # 원핫 인코딩 적용
    A['New'] = A['New'].apply(one_hot_encode)
    
    for n in range(len(A)):
        B = []
        for n_1 in range(21):
            B.append(A.loc[n, 'Original'][0][n_1].tolist())
            
        B.append(A.loc[n, 'Position'])
        
        for n_2 in range(21):
            B.append(A.loc[n, 'New'][0][n_2].tolist())
            
        X[i] = X[i].astype('str')
        X.at[n, i] = B

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
# 데이터프레임 생성 (이미 생성된 데이터프레임 X 사용)
# 'Original_padded_sequences'에서 리스트를 행렬로 변환
X['Original_padded_sequences'] = X['Original_padded_sequences'].apply(lambda x: np.array(x))

# %%
# 특성과 레이블 설정
X_padded = np.vstack(X['Original_padded_sequences'].values)  # 리스트를 행렬로 변환
Position = X['Position'].values  # Position 열
New = np.vstack(X['New'].values)  # New 열을 행렬로 변환 (2D 배열로 변환)
y = X['SUBCLASS']  # 타겟 레이블

# 특성 행렬 결합: Original_padded_sequences, Position, New
X_features = np.hstack((X_padded, Position.reshape(-1, 1), New))  # New 열을 추가

# %%
# 데이터셋을 학습 세트와 테스트 세트로 분리
X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.2, random_state=42)

# XGBoost 모델 생성
model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# 모델 학습
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
model.score(X_train, y_train)
# Out:
# 0.21471774193548387

# %%
# 테스트 세트에 대한 예측 수행
y_pred = model.predict(X_test)

# 정확도 평가
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.13
